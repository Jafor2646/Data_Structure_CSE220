# %%
eb = [[None]*10, [None]*10]
inp1 = input()
inp2 = input()
if(len(inp1) > 10 or len(inp2) > 10):
  print("Invalid Input Size")
else:
  print("Your input is valid. Press any key and then press enter to continue!!!")
  fsi = 0
  ssi = 0
  for i in range(len(inp1)):
    if(ord(inp1[i]) >= 65 and ord(inp1[i]) <= 90):
      fsi = i
    eb[0][i] = inp1[i]
  for i in range(len(inp2)):
    if(ord(inp2[i]) >= 65 and ord(inp2[i]) <= 90):
      ssi = i
    eb[1][i] = inp2[i]
  # for i in range(len(inp1)):
  #   eb[0][i] = inp1[i]
  # for i in range(len(inp2)):
  #   eb[1][i] = inp2[i]
  print("Top Board Start Character:", eb[0][fsi])
  print("Top Board Start Index:", fsi)
  print("Bottom Board Start Character:", eb[1][ssi])
  print("Bottom Board Start Index:", ssi)
  temp1 = fsi
  temp2 = ssi
  while True:
    inp = input("Press any key and then press enter to continue!!!")
    if(inp == 'q' or inp == 'Q'):
      break
    index1 = temp1
    index2 = temp2
    for i in range(len(eb[0])):
      print(eb[0][index1],end="")
      index1 = (index1-1) % len(eb[0])
    print()
    for i in range(len(eb[1])):
      print(eb[1][index2],end="")
      index2 = (index2 + 1) % len(eb[1])
    print()
    temp1 = (temp1-1) % len(eb[0])
    temp2 = (temp2+1) % len(eb[1])
  print("Top Board Start Character:", eb[0][fsi])
  print("Top Board Start Index:", fsi)
  print("Bottom Board Start Character:", eb[1][ssi])
  print("Bottom Board Start Index:", ssi)
# Out:
# giRtfel2th
# rightLeft2
# Your input is valid. Press any key and then press enter to continue!!!
# Top Board Start Character: R
# Top Board Start Index: 2
# Bottom Board Start Character: L
# Bottom Board Start Index: 5
# Press any key and then press enter to continue!!!a
# Right2left
# Left2right
# Press any key and then press enter to continue!!!s
# ight2leftR
# eft2rightL
# Press any key and then press enter to continue!!!f
# ght2leftRi
# ft2rightLe
# Press any key and then press enter to continue!!!q
# Top Board Start Character: R
# Top Board Start Index: 2
# Bottom Board Start Character: L
# Bottom Board Start Index: 5
